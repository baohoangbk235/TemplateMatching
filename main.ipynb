# %%
# %cd /content/drive/MyDrive/DATN
# Out:
# /content/drive/MyDrive/DATN

# %%
# !pip install pillow==7.1 albumentations==0.4.6 PyYAML craft-text-detector &> /dev/null

# %%
# %ls dataset/train
# Out:
# 'Template 10'/  'Template 2'/  'Template 4'/  'Template 6'/
# 'Template 11'/  'Template 3'/  'Template 5'/  'Template 8'/

# %%
# !python train.py
# Out:
# {'PRJ_DIR': '/content/drive/MyDrive/Workspace/TemplateClassification', 'REFINER_WEIGHT': 'weights/pretrained/craft_refiner_CTW1500.pth', 'CRAFT_WEIGHT': 'weights/pretrained/1117_23.833.pth', 'DATA_DIR': 'dataset/train/', 'OUT_DIR': 'dataset/preprocessed_train/', 'num_epochs': 30, 'train_data': 'dataset/train/', 'val_data': 'dataset/val/', 'test_data': 'dataset/test/', 'batch_size': 16, 'learning_rate': 0.0001, 'weight_decay': 1e-06}
# [INFO] Processing dataset ...
# Epoch 1:   0% 0/53 [00:01<?, ?batch/s]
# Traceback (most recent call last):
#   File "train.py", line 255, in <module>
#     train()
#   File "train.py", line 250, in train
#     train_one_epoch(epoch, trainloader, model, optimizer, scheduler, triplet_loss, loss_history)
#   File "train.py", line 186, in train_one_epoch
#     neg_emb = model(negatives)
#   File "/usr/local/lib/python3.7/dist-packages/torch/nn/modules/module.py", line 889, in _call_impl
#     result = self.forward(*input, **kwargs)
# ...
